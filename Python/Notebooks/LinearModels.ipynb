# %% [markdown]
# # Text Preprocessing and Linear Analysis

# %% [markdown]
# Required libraries:
# - [Numpy](http://www.numpy.org) — a package for scientific computing.
# - [Pandas](https://pandas.pydata.org) — a library providing high-performance, easy-to-use data structures and data analysis tools for the Python
# - [scikit-learn](http://scikit-learn.org/stable/index.html) — a tool for data mining and data analysis.
# - [NLTK](http://www.nltk.org) — a platform to work with natural language.

# %% [markdown]
# ## Data
# - Import the data using the correct data structure as generated by your processing script
# - Set up the training, validation and test data

# %% [markdown]
# ## Preprocess text
# - Replace symbols with spaces
# - Remove stopwords

# %% [markdown]
# ## Vectorize text (BOW)
# - Produce Bag-of-words representation for the phrases stated
# - Extend the BOW with IF-IDF

# %% [markdown]
# ## Analysis
# - Do nothing for now (will need more data)
